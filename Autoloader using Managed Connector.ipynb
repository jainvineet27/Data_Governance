-- %% [markdown]
-- We would be connecting a extenral source here we have prepare a SQL Server  with details sqladmin and my password  and servername namastevineet
-- databaseame vineetdb
--
-- Now my databricks we would be using managed connector

-- %%
show groups

-- %%
select  current_catalog()  , current_user() , is_account_group_member('admins')
