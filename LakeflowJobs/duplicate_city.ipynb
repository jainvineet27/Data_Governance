# %%
cities_object =spark.sql("select distinct city from namaste_catalog.jobs.orders_silver").collect()
cities =[]
for city in cities_object:
    cities.append(city.city)


dbutils.jobs.taskValues.set(key  = "cities" , value = cities)
